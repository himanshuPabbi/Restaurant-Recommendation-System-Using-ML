# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import r2_score
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
import re
from nltk.corpus import stopwords
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
zomato_real=pd.read_csv("zomato.csv")
zomato_real.head() # prints the first 5 rows of the dataset
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# 1          Yes         No  4.1/5    787                      080 41714161
# 2          Yes         No  3.8/5    918                    +91 9663487993
# 3           No         No  3.7/5     88                    +91 9620009302
# 4           No         No  3.8/5    166  +91 8026612447\r\n+91 9901210005
#
#        location            rest_type  \
# 0  Banashankari        Casual Dining
# 1  Banashankari        Casual Dining
# 2  Banashankari  Cafe, Casual Dining
# 3  Banashankari          Quick Bites
# 4  Basavanagudi        Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2  Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                        Masala Dosa
# 4                                Panipuri, Gol Gappe
#
#                          cuisines approx_cost(for two people)  \
# 0  North Indian, Mughlai, Chinese                         800
# 1     Chinese, North Indian, Thai                         800
# 2          Cafe, Mexican, Italian                         800
# 3      South Indian, North Indian                         300
# 4        North Indian, Rajasthani                         600
#
#                                         reviews_list menu_item  \
# 0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
#
#   listed_in(type) listed_in(city)
# 0          Buffet    Banashankari
# 1          Buffet    Banashankari
# 2          Buffet    Banashankari
# 3          Buffet    Banashankari
# 4          Buffet    Banashankari

# %%
#Deleting Unnnecessary Columns
zomato=zomato_real.drop(['url','dish_liked','phone'],axis=1) #Dropping the column "dish_liked", "phone", "url" and saving the new dataset as "zomato"

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51712         No  3.6 /5     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                cuisines  \
# 0            Casual Dining          North Indian, Mughlai, Chinese
# 1            Casual Dining             Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                  Cafe, Mexican, Italian
# 3              Quick Bites              South Indian, North Indian
# 4            Casual Dining                North Indian, Rajasthani
# ...                    ...                                     ...
# 51712                  Bar                             Continental
# 51713                  Bar                             Finger Food
# 51714                  Bar                             Finger Food
# 51715                  Bar                             Finger Food
# 51716   Bar, Casual Dining  Finger Food, North Indian, Continental
#
#       approx_cost(for two people)  \
# 0                             800
# 1                             800
# 2                             800
# 3                             300
# 4                             600
# ...                           ...
# 51712                       1,500
# 51713                         600
# 51714                       2,000
# 51715                       2,500
# 51716                       1,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51713                                                 []        []
# 51714                                                 []        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51712   Pubs and bars      Whitefield
# 51713   Pubs and bars      Whitefield
# 51714   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [51717 rows x 14 columns]

# %%
#Removing the Duplicates
zomato.duplicated().sum()
zomato.drop_duplicates(inplace=True)

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51712         No  3.6 /5     27                  Whitefield
# 51713         No     NaN      0                  Whitefield
# 51714         No     NaN      0                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                cuisines  \
# 0            Casual Dining          North Indian, Mughlai, Chinese
# 1            Casual Dining             Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                  Cafe, Mexican, Italian
# 3              Quick Bites              South Indian, North Indian
# 4            Casual Dining                North Indian, Rajasthani
# ...                    ...                                     ...
# 51712                  Bar                             Continental
# 51713                  Bar                             Finger Food
# 51714                  Bar                             Finger Food
# 51715                  Bar                             Finger Food
# 51716   Bar, Casual Dining  Finger Food, North Indian, Continental
#
#       approx_cost(for two people)  \
# 0                             800
# 1                             800
# 2                             800
# 3                             300
# 4                             600
# ...                           ...
# 51712                       1,500
# 51713                         600
# 51714                       2,000
# 51715                       2,500
# 51716                       1,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51713                                                 []        []
# 51714                                                 []        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51712   Pubs and bars      Whitefield
# 51713   Pubs and bars      Whitefield
# 51714   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [51674 rows x 14 columns]

# %%
#Remove the NaN values from the dataset
zomato.isnull().sum()
zomato.dropna(how='any',inplace=True)

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51709                         The Farm House Bar n Grill           No
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51709         No  3.7 /5     34                  Whitefield
# 51711         No  2.5 /5     81                  Whitefield
# 51712         No  3.6 /5     27                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 51709   Casual Dining, Bar                    North Indian, Continental
# 51711   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 51712                  Bar                                  Continental
# 51715                  Bar                                  Finger Food
# 51716   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#       approx_cost(for two people)  \
# 0                             800
# 1                             800
# 2                             800
# 3                             300
# 4                             600
# ...                           ...
# 51709                         800
# 51711                         800
# 51712                       1,500
# 51715                       2,500
# 51716                       1,500
#
#                                             reviews_list menu_item  \
# 0      [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...                                                  ...       ...
# 51709  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 51711  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 51712  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51715  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#       listed_in(type) listed_in(city)
# 0              Buffet    Banashankari
# 1              Buffet    Banashankari
# 2              Buffet    Banashankari
# 3              Buffet    Banashankari
# 4              Buffet    Banashankari
# ...               ...             ...
# 51709   Pubs and bars      Whitefield
# 51711   Pubs and bars      Whitefield
# 51712   Pubs and bars      Whitefield
# 51715   Pubs and bars      Whitefield
# 51716   Pubs and bars      Whitefield
#
# [43499 rows x 14 columns]

# %%
#Changing the column names
zomato = zomato.rename(columns={'approx_cost(for two people)':'cost','listed_in(type)':'type', 'listed_in(city)':'city'})

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51709                         The Farm House Bar n Grill           No
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51709         No  3.7 /5     34                  Whitefield
# 51711         No  2.5 /5     81                  Whitefield
# 51712         No  3.6 /5     27                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 51709   Casual Dining, Bar                    North Indian, Continental
# 51711   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 51712                  Bar                                  Continental
# 51715                  Bar                                  Finger Food
# 51716   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0        800  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1        800  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2        800  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3        300  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4        600  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 51709    800  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 51711    800  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 51712  1,500  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51715  2,500  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716  1,500  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city
# 0             Buffet  Banashankari
# 1             Buffet  Banashankari
# 2             Buffet  Banashankari
# 3             Buffet  Banashankari
# 4             Buffet  Banashankari
# ...              ...           ...
# 51709  Pubs and bars    Whitefield
# 51711  Pubs and bars    Whitefield
# 51712  Pubs and bars    Whitefield
# 51715  Pubs and bars    Whitefield
# 51716  Pubs and bars    Whitefield
#
# [43499 rows x 14 columns]

# %%
#Some Transformations
zomato['cost'] = zomato['cost'].astype(str) #Changing the cost to string
zomato['cost'] = zomato['cost'].apply(lambda x: x.replace(',','.')) #Using lambda function to replace ',' from cost
zomato['cost'] = zomato['cost'].astype(float)

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51709  136, SAP Labs India, KIADB Export Promotion In...
# 51711  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 51709                         The Farm House Bar n Grill           No
# 51711                                            Bhagini           No
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 51716                       The Nest - The Den Bengaluru           No
#
#       book_table    rate  votes                    location  \
# 0            Yes   4.1/5    775                Banashankari
# 1             No   4.1/5    787                Banashankari
# 2             No   3.8/5    918                Banashankari
# 3             No   3.7/5     88                Banashankari
# 4             No   3.8/5    166                Basavanagudi
# ...          ...     ...    ...                         ...
# 51709         No  3.7 /5     34                  Whitefield
# 51711         No  2.5 /5     81                  Whitefield
# 51712         No  3.6 /5     27                  Whitefield
# 51715        Yes  4.3 /5    236  ITPL Main Road, Whitefield
# 51716         No  3.4 /5     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 51709   Casual Dining, Bar                    North Indian, Continental
# 51711   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 51712                  Bar                                  Continental
# 51715                  Bar                                  Finger Food
# 51716   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      800.0  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      800.0  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      300.0  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      600.0  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 51709  800.0  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 51711  800.0  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 51712    1.5  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 51715    2.5  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 51716    1.5  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city
# 0             Buffet  Banashankari
# 1             Buffet  Banashankari
# 2             Buffet  Banashankari
# 3             Buffet  Banashankari
# 4             Buffet  Banashankari
# ...              ...           ...
# 51709  Pubs and bars    Whitefield
# 51711  Pubs and bars    Whitefield
# 51712  Pubs and bars    Whitefield
# 51715  Pubs and bars    Whitefield
# 51716  Pubs and bars    Whitefield
#
# [43499 rows x 14 columns]

# %%
#Removing '/5' from Rates
zomato = zomato.loc[zomato.rate !='NEW']
zomato = zomato.loc[zomato.rate !='-'].reset_index(drop=True)
remove_slash = lambda x: x.replace('/5', '') if type(x) == str else x
zomato.rate = zomato.rate.apply(remove_slash).str.strip().astype('float')

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# 2                                        San Churro Cafe          Yes
# 3                                  Addhuri Udupi Bhojana           No
# 4                                          Grand Village           No
# ...                                                  ...          ...
# 41232                         The Farm House Bar n Grill           No
# 41233                                            Bhagini           No
# 41234  Best Brews - Four Points by Sheraton Bengaluru...           No
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...           No
# 41236                       The Nest - The Den Bengaluru           No
#
#       book_table  rate  votes                    location  \
# 0            Yes   4.1    775                Banashankari
# 1             No   4.1    787                Banashankari
# 2             No   3.8    918                Banashankari
# 3             No   3.7     88                Banashankari
# 4             No   3.8    166                Basavanagudi
# ...          ...   ...    ...                         ...
# 41232         No   3.7     34                  Whitefield
# 41233         No   2.5     81                  Whitefield
# 41234         No   3.6     27                  Whitefield
# 41235        Yes   4.3    236  ITPL Main Road, Whitefield
# 41236         No   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      800.0  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      800.0  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      300.0  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      600.0  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 41232  800.0  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 41233  800.0  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 41234    1.5  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 41235    2.5  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 41236    1.5  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city
# 0             Buffet  Banashankari
# 1             Buffet  Banashankari
# 2             Buffet  Banashankari
# 3             Buffet  Banashankari
# 4             Buffet  Banashankari
# ...              ...           ...
# 41232  Pubs and bars    Whitefield
# 41233  Pubs and bars    Whitefield
# 41234  Pubs and bars    Whitefield
# 41235  Pubs and bars    Whitefield
# 41236  Pubs and bars    Whitefield
#
# [41237 rows x 14 columns]

# %%
# Adjust the column names
zomato.name = zomato.name.apply(lambda x:x.title())
zomato.online_order.replace(('Yes','No'),(True, False),inplace=True)
zomato.book_table.replace(('Yes','No'),(True, False),inplace=True)

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      800.0  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      800.0  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      300.0  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      600.0  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 41232  800.0  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 41233  800.0  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 41234    1.5  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 41235    2.5  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 41236    1.5  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city
# 0             Buffet  Banashankari
# 1             Buffet  Banashankari
# 2             Buffet  Banashankari
# 3             Buffet  Banashankari
# 4             Buffet  Banashankari
# ...              ...           ...
# 41232  Pubs and bars    Whitefield
# 41233  Pubs and bars    Whitefield
# 41234  Pubs and bars    Whitefield
# 41235  Pubs and bars    Whitefield
# 41236  Pubs and bars    Whitefield
#
# [41237 rows x 14 columns]

# %%
## Computing Mean Rating
restaurants = list(zomato['name'].unique())
zomato['Mean Rating'] = 0

for i in range(len(restaurants)):
    zomato['Mean Rating'][zomato['name'] == restaurants[i]] = zomato['rate'][zomato['name'] == restaurants[i]].mean()

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      800.0  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      800.0  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      300.0  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      600.0  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 41232  800.0  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 41233  800.0  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 41234    1.5  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 41235    2.5  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 41236    1.5  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari     4.118182
# 1             Buffet  Banashankari     4.100000
# 2             Buffet  Banashankari     3.800000
# 3             Buffet  Banashankari     3.700000
# 4             Buffet  Banashankari     3.800000
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield     3.700000
# 41233  Pubs and bars    Whitefield     2.283333
# 41234  Pubs and bars    Whitefield     3.600000
# 41235  Pubs and bars    Whitefield     4.300000
# 41236  Pubs and bars    Whitefield     3.400000
#
# [41237 rows x 15 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (1,5))
zomato[['Mean Rating']] = scaler.fit_transform(zomato[['Mean Rating']]).round(2)

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  [('Rated 4.0', 'RATED\n  A beautiful place to ...        []
# 1      800.0  [('Rated 4.0', 'RATED\n  Had been here for din...        []
# 2      800.0  [('Rated 3.0', "RATED\n  Ambience is not that ...        []
# 3      300.0  [('Rated 4.0', "RATED\n  Great food and proper...        []
# 4      600.0  [('Rated 4.0', 'RATED\n  Very good restaurant ...        []
# ...      ...                                                ...       ...
# 41232  800.0  [('Rated 4.0', 'RATED\n  Ambience- Big and spa...        []
# 41233  800.0  [('Rated 4.0', 'RATED\n  A fine place to chill...        []
# 41234    1.5  [('Rated 5.0', "RATED\n  Food and service are ...        []
# 41235    2.5  [('Rated 4.0', 'RATED\n  Nice and friendly pla...        []
# 41236    1.5  [('Rated 5.0', 'RATED\n  Great ambience , look...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
## Lower Casing
zomato["reviews_list"] = zomato["reviews_list"].str.lower()

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  [('rated 4.0', 'rated\n  a beautiful place to ...        []
# 1      800.0  [('rated 4.0', 'rated\n  had been here for din...        []
# 2      800.0  [('rated 3.0', "rated\n  ambience is not that ...        []
# 3      300.0  [('rated 4.0', "rated\n  great food and proper...        []
# 4      600.0  [('rated 4.0', 'rated\n  very good restaurant ...        []
# ...      ...                                                ...       ...
# 41232  800.0  [('rated 4.0', 'rated\n  ambience- big and spa...        []
# 41233  800.0  [('rated 4.0', 'rated\n  a fine place to chill...        []
# 41234    1.5  [('rated 5.0', "rated\n  food and service are ...        []
# 41235    2.5  [('rated 4.0', 'rated\n  nice and friendly pla...        []
# 41236    1.5  [('rated 5.0', 'rated\n  great ambience , look...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
## Removal of Puctuations
import string
PUNCT_TO_REMOVE = string.punctuation
def remove_punctuation(text):
    """custom function to remove the punctuation"""
    return text.translate(str.maketrans('', '', PUNCT_TO_REMOVE))

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_punctuation(text))

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  rated 40 ratedn  a beautiful place to dine int...        []
# 1      800.0  rated 40 ratedn  had been here for dinner with...        []
# 2      800.0  rated 30 ratedn  ambience is not that good eno...        []
# 3      300.0  rated 40 ratedn  great food and proper karnata...        []
# 4      600.0  rated 40 ratedn  very good restaurant in neigh...        []
# ...      ...                                                ...       ...
# 41232  800.0  rated 40 ratedn  ambience big and spacious law...        []
# 41233  800.0  rated 40 ratedn  a fine place to chill after o...        []
# 41234    1.5  rated 50 ratedn  food and service are incompar...        []
# 41235    2.5  rated 40 ratedn  nice and friendly place and s...        []
# 41236    1.5  rated 50 ratedn  great ambience  looking nice ...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
## Removal of Stopwords
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_stopwords(text))

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  rated 40 ratedn beautiful place dine inthe int...        []
# 1      800.0  rated 40 ratedn dinner family turned good choo...        []
# 2      800.0  rated 30 ratedn ambience good enough pocket fr...        []
# 3      300.0  rated 40 ratedn great food proper karnataka st...        []
# 4      600.0  rated 40 ratedn good restaurant neighbourhood ...        []
# ...      ...                                                ...       ...
# 41232  800.0  rated 40 ratedn ambience big spacious lawn use...        []
# 41233  800.0  rated 40 ratedn fine place chill office hours ...        []
# 41234    1.5  rated 50 ratedn food service incomparably exce...        []
# 41235    2.5  rated 40 ratedn nice friendly place staff awes...        []
# 41236    1.5  rated 50 ratedn great ambience looking nice go...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
## Removal of URLS
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    return url_pattern.sub(r'', text)

zomato["reviews_list"] = zomato["reviews_list"].apply(lambda text: remove_urls(text))

zomato[['reviews_list', 'cuisines']].sample(5)
# Out:
#                                             reviews_list  \
# 340    rated 30 ratedn located behind south end metro...
# 37529  rated 40 ratedn small outlet inside hypercity ...
# 33176  rated 40 ratedn regular hereever holiday used ...
# 39041  rated 45 ratedn nice experience gone couple fr...
# 32875  rated 30 ratedn ordered special dabeli khakhra...
#
#                              cuisines
# 340                             Rolls
# 37529                  Tibetan, Momos
# 33176  North Indian, Chinese, Mughlai
# 39041  Chinese, Italian, North Indian
# 32875             Gujarati, Fast Food

# %%
zomato
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate  votes                    location  \
# 0            True   4.1    775                Banashankari
# 1           False   4.1    787                Banashankari
# 2           False   3.8    918                Banashankari
# 3           False   3.7     88                Banashankari
# 4           False   3.8    166                Basavanagudi
# ...           ...   ...    ...                         ...
# 41232       False   3.7     34                  Whitefield
# 41233       False   2.5     81                  Whitefield
# 41234       False   3.6     27                  Whitefield
# 41235        True   4.3    236  ITPL Main Road, Whitefield
# 41236       False   3.4     13  ITPL Main Road, Whitefield
#
#                  rest_type                                     cuisines  \
# 0            Casual Dining               North Indian, Mughlai, Chinese
# 1            Casual Dining                  Chinese, North Indian, Thai
# 2      Cafe, Casual Dining                       Cafe, Mexican, Italian
# 3              Quick Bites                   South Indian, North Indian
# 4            Casual Dining                     North Indian, Rajasthani
# ...                    ...                                          ...
# 41232   Casual Dining, Bar                    North Indian, Continental
# 41233   Casual Dining, Bar  Andhra, South Indian, Chinese, North Indian
# 41234                  Bar                                  Continental
# 41235                  Bar                                  Finger Food
# 41236   Bar, Casual Dining       Finger Food, North Indian, Continental
#
#         cost                                       reviews_list menu_item  \
# 0      800.0  rated 40 ratedn beautiful place dine inthe int...        []
# 1      800.0  rated 40 ratedn dinner family turned good choo...        []
# 2      800.0  rated 30 ratedn ambience good enough pocket fr...        []
# 3      300.0  rated 40 ratedn great food proper karnataka st...        []
# 4      600.0  rated 40 ratedn good restaurant neighbourhood ...        []
# ...      ...                                                ...       ...
# 41232  800.0  rated 40 ratedn ambience big spacious lawn use...        []
# 41233  800.0  rated 40 ratedn fine place chill office hours ...        []
# 41234    1.5  rated 50 ratedn food service incomparably exce...        []
# 41235    2.5  rated 40 ratedn nice friendly place staff awes...        []
# 41236    1.5  rated 50 ratedn great ambience looking nice go...        []
#
#                 type          city  Mean Rating
# 0             Buffet  Banashankari         3.99
# 1             Buffet  Banashankari         3.97
# 2             Buffet  Banashankari         3.58
# 3             Buffet  Banashankari         3.45
# 4             Buffet  Banashankari         3.58
# ...              ...           ...          ...
# 41232  Pubs and bars    Whitefield         3.45
# 41233  Pubs and bars    Whitefield         1.62
# 41234  Pubs and bars    Whitefield         3.32
# 41235  Pubs and bars    Whitefield         4.23
# 41236  Pubs and bars    Whitefield         3.06
#
# [41237 rows x 15 columns]

# %%
# RESTAURANT NAMES:
restaurant_names = list(zomato['name'].unique())
def get_top_words(column, top_nu_of_words, nu_of_word):
    vec = CountVectorizer(ngram_range= nu_of_word, stop_words='english')
    bag_of_words = vec.fit_transform(column)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:top_nu_of_words]
    
zomato=zomato.drop(['address','rest_type', 'type', 'menu_item', 'votes'],axis=1)

# %%
zomato
# Out:
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 41232                         The Farm House Bar N Grill         False
# 41233                                            Bhagini         False
# 41234  Best Brews - Four Points By Sheraton Bengaluru...         False
# 41235  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 41236                       The Nest - The Den Bengaluru         False
#
#        book_table  rate                    location  \
# 0            True   4.1                Banashankari
# 1           False   4.1                Banashankari
# 2           False   3.8                Banashankari
# 3           False   3.7                Banashankari
# 4           False   3.8                Basavanagudi
# ...           ...   ...                         ...
# 41232       False   3.7                  Whitefield
# 41233       False   2.5                  Whitefield
# 41234       False   3.6                  Whitefield
# 41235        True   4.3  ITPL Main Road, Whitefield
# 41236       False   3.4  ITPL Main Road, Whitefield
#
#                                           cuisines   cost  \
# 0                   North Indian, Mughlai, Chinese  800.0
# 1                      Chinese, North Indian, Thai  800.0
# 2                           Cafe, Mexican, Italian  800.0
# 3                       South Indian, North Indian  300.0
# 4                         North Indian, Rajasthani  600.0
# ...                                            ...    ...
# 41232                    North Indian, Continental  800.0
# 41233  Andhra, South Indian, Chinese, North Indian  800.0
# 41234                                  Continental    1.5
# 41235                                  Finger Food    2.5
# 41236       Finger Food, North Indian, Continental    1.5
#
#                                             reviews_list          city  \
# 0      rated 40 ratedn beautiful place dine inthe int...  Banashankari
# 1      rated 40 ratedn dinner family turned good choo...  Banashankari
# 2      rated 30 ratedn ambience good enough pocket fr...  Banashankari
# 3      rated 40 ratedn great food proper karnataka st...  Banashankari
# 4      rated 40 ratedn good restaurant neighbourhood ...  Banashankari
# ...                                                  ...           ...
# 41232  rated 40 ratedn ambience big spacious lawn use...    Whitefield
# 41233  rated 40 ratedn fine place chill office hours ...    Whitefield
# 41234  rated 50 ratedn food service incomparably exce...    Whitefield
# 41235  rated 40 ratedn nice friendly place staff awes...    Whitefield
# 41236  rated 50 ratedn great ambience looking nice go...    Whitefield
#
#        Mean Rating
# 0             3.99
# 1             3.97
# 2             3.58
# 3             3.45
# 4             3.58
# ...            ...
# 41232         3.45
# 41233         1.62
# 41234         3.32
# 41235         4.23
# 41236         3.06
#
# [41237 rows x 10 columns]

# %%
import pandas

# Randomly sample 60% of your dataframe
df_percent = zomato.sample(frac=0.5)

# %%
df_percent.set_index('name', inplace=True)

# %%
df_percent
# Out:
#                        online_order  book_table  rate               location  \
# name
# Chetty'S Corner                True       False   3.8  Koramangala 5th Block
# Friends Night Kitchen          True       False   3.8  Koramangala 6th Block
# Freshmenu                      True       False   3.8        South Bangalore
# Khushi Kitchen                 True       False   3.3           Thippasandra
# Midnight Special               True       False   3.7                    HSR
# ...                             ...         ...   ...                    ...
# Andhra Kafe                    True       False   3.8             Whitefield
# Juicy                         False       False   3.9  Koramangala 5th Block
# Ghee Biryanis                  True       False   3.4                    BTM
# Keshava Kabab Centre          False       False   3.2               JP Nagar
# Biso - Citrus Hotels          False        True   3.9        Cunningham Road
#
#                                                                 cuisines  \
# name
# Chetty'S Corner                                        Fast Food, Burger
# Friends Night Kitchen                                     Italian, Pizza
# Freshmenu              Healthy Food, Chinese, Biryani, North Indian, ...
# Khushi Kitchen                 Street Food, North Indian, Bengali, Oriya
# Midnight Special                        North Indian, Fast Food, Chinese
# ...                                                                  ...
# Andhra Kafe                  Andhra, South Indian, North Indian, Biryani
# Juicy                                       Beverages, Juices, Fast Food
# Ghee Biryanis                                      Biryani, North Indian
# Keshava Kabab Centre                                        North Indian
# Biso - Citrus Hotels    North Indian, South Indian, Italian, Continental
#
#                         cost  \
# name
# Chetty'S Corner        200.0
# Friends Night Kitchen  400.0
# Freshmenu              450.0
# Khushi Kitchen         400.0
# Midnight Special       500.0
# ...                      ...
# Andhra Kafe            550.0
# Juicy                  200.0
# Ghee Biryanis          500.0
# Keshava Kabab Centre   200.0
# Biso - Citrus Hotels     1.1
#
#                                                             reviews_list  \
# name
# Chetty'S Corner        rated 50 ratedn loved foodnwe ordered placengo...
# Friends Night Kitchen  rated 10 ratedn pizza way dryno chess cold wou...
# Freshmenu              rated 50 ratedn continental foodnnonline deliv...
# Khushi Kitchen         rated 50 ratedn absolutely love guysni order a...
# Midnight Special
# ...                                                                  ...
# Andhra Kafe            rated 30 ratedn couple friends ordered muttun ...
# Juicy                  rated 50 ratedn love chicken mayo sandwich ive...
# Ghee Biryanis          rated 30 ratedn biryani quite good tastenmanag...
# Keshava Kabab Centre   rated 30 ratedn last week went place take away...
# Biso - Citrus Hotels   rated 40 ratedn convenient lunch option cunnin...
#
#                                         city  Mean Rating
# name
# Chetty'S Corner                          BTM         3.43
# Friends Night Kitchen              Jayanagar         3.58
# Freshmenu                           JP Nagar         3.33
# Khushi Kitchen                   Indiranagar         3.03
# Midnight Special       Koramangala 5th Block         3.45
# ...                                      ...          ...
# Andhra Kafe                       Whitefield         3.58
# Juicy                  Koramangala 6th Block         3.67
# Ghee Biryanis                       JP Nagar         3.12
# Keshava Kabab Centre               Jayanagar         2.81
# Biso - Citrus Hotels                 MG Road         3.50
#
# [20618 rows x 9 columns]

# %%
indices = pd.Series(df_percent.index)

# %%
indices
# Out:
# 0              Chetty'S Corner
# 1        Friends Night Kitchen
# 2                    Freshmenu
# 3               Khushi Kitchen
# 4             Midnight Special
#                  ...
# 20613              Andhra Kafe
# 20614                    Juicy
# 20615            Ghee Biryanis
# 20616     Keshava Kabab Centre
# 20617     Biso - Citrus Hotels
# Name: name, Length: 20618, dtype: object

# %%
# Creating tf-idf matrix
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0, stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_percent['reviews_list'])

# %%
tfidf_matrix
# Out:
# <20618x1370492 sparse matrix of type '<class 'numpy.float64'>'
# 	with 11426227 stored elements in Compressed Sparse Row format>

# %%
cosine_similarities = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_similarities
# Out:
# array([[1.        , 0.08106051, 0.00662799, ..., 0.00760653, 0.00385504,
#         0.01685461],
#        [0.08106051, 1.        , 0.06203319, ..., 0.02760158, 0.03463073,
#         0.05745327],
#        [0.00662799, 0.06203319, 1.        , ..., 0.01636466, 0.01909293,
#         0.02316172],
#        ...,
#        [0.00760653, 0.02760158, 0.01636466, ..., 1.        , 0.01357752,
#         0.02332678],
#        [0.00385504, 0.03463073, 0.01909293, ..., 0.01357752, 1.        ,
#         0.02219776],
#        [0.01685461, 0.05745327, 0.02316172, ..., 0.02332678, 0.02219776,
#         1.        ]])

# %%
def recommend(name, cosine_similarities = cosine_similarities):
    
    # Create a list to put top restaurants
    recommend_restaurant = []
    
    # Find the index of the hotel entered
    idx = indices[indices == name].index[0]
    print("Find the index of the hotel entered",idx)
    # Find the restaurants with a similar cosine-sim value and order them from bigges number
    score_series = pd.Series(cosine_similarities[idx]).sort_values(ascending=False)
    print("Find the restaurants with a similar cosine-sim value and order them from bigges number")

    print(score_series)
    # Extract top 30 restaurant indexes with a similar cosine-sim value
    top30_indexes = list(score_series.iloc[0:31].index)
    print("Extract top 30 restaurant indexes with a similar cosine-sim value")

    print(top30_indexes)
    # Names of the top 30 restaurants
    for each in top30_indexes:
        recommend_restaurant.append(list(df_percent.index)[each])
    print(recommend_restaurant)
    # Creating the new data set to show similar restaurants
    print("Creating the new data set to show similar restaurants")
    df_new = pd.DataFrame(columns=['cuisines', 'Mean Rating', 'cost'])
    print(df_new)
    print("Create the top 30 similar restaurants with some of their columns")
    # Create the top 30 similar restaurants with some of their columns
    for each in recommend_restaurant:
        df_new = df_new.append(pd.DataFrame(df_percent[['cuisines','Mean Rating', 'cost']][df_percent.index == each].sample()))
    
    print(df_new)
    # Drop the same named restaurants and sort only the top 10 by the highest rating
    print("# Drop the same named restaurants and sort only the top 10 by the highest rating")
    df_new = df_new.drop_duplicates(subset=['cuisines','Mean Rating', 'cost'], keep=False)
    print(df_new)
    df_new = df_new.sort_values(by='Mean Rating', ascending=False).head(10)
    
    print(df_new)
    print('TOP %s RESTAURANTS LIKE %s WITH SIMILAR REVIEWS: ' % (str(len(df_new)), name))
    
    return df_new
recommend('Pai Vihar')
# Out:
# Find the index of the hotel entered 2068
# Find the restaurants with a similar cosine-sim value and order them from bigges number
# 3941     1.000000
# 2068     1.000000
# 14147    0.675432
# 4211     0.675432
# 8993     0.079553
#            ...
# 4480     0.000000
# 19580    0.000000
# 4486     0.000000
# 12425    0.000000
# 1672     0.000000
# Length: 20618, dtype: float64
# Extract top 30 restaurant indexes with a similar cosine-sim value
# [3941, 2068, 14147, 4211, 8993, 7206, 20505, 241, 13315, 9046, 2310, 19588, 6236, 20217, 11681, 1992, 2862, 9401, 4706, 2450, 9655, 14549, 2103, 16522, 7763, 16078, 4934, 14775, 1984, 6870, 14655]
# ['Pai Vihar', 'Pai Vihar', 'Pai Vihar', 'Pai Vihar', 'Shree Thali', 'Shree Thali', 'Mast Kalandar', 'Mast Kalandar', 'Gokul Kuteera', 'Prasiddhi Food Corner', 'Delhi Home Food', 'Delhi Home Food', 'Delhi Home Food', 'Punjabi Tasty Khana', 'Prasiddhi Food Corner', 'Punjabi Dawat', 'Melange - Hotel Ekaa', 'Food Point', 'Melange - Hotel Ekaa', 'Agarwal Food Service', 'A2B - Adyar Ananda Bhavan', 'Sri Lakshmi Dhaba', 'Sri Krishna Kitchen', 'Melange - Hotel Ekaa', 'Swad Punjab Da', 'Bitebox', 'Mast Kalandar', 'Ghar Ka Khana', 'Melange - Hotel Ekaa', 'The Diner', 'Swad Punjab Da']
# Creating the new data set to show similar restaurants
# Empty DataFrame
# Columns: [cuisines, Mean Rating, cost]
# Index: []
# Create the top 30 similar restaurants with some of their columns
#                                                                     cuisines  \
# Pai Vihar                      South Indian, Street Food, Chinese, Fast Food
# Pai Vihar                      South Indian, Street Food, Chinese, Fast Food
# Pai Vihar                      South Indian, Street Food, Chinese, Fast Food
# Pai Vihar                      South Indian, Street Food, Chinese, Fast Food
# Shree Thali                                                     North Indian
# Shree Thali                                                     North Indian
# Mast Kalandar                                                   North Indian
# Mast Kalandar                                                   North Indian
# Gokul Kuteera                                          North Indian, Chinese
# Prasiddhi Food Corner                  Fast Food, North Indian, South Indian
# Delhi Home Food                                   North Indian, South Indian
# Delhi Home Food                                   North Indian, South Indian
# Delhi Home Food                                   North Indian, South Indian
# Punjabi Tasty Khana                           North Indian, Chinese, Biryani
# Prasiddhi Food Corner                  Fast Food, North Indian, South Indian
# Punjabi Dawat                                          North Indian, Chinese
# Melange - Hotel Ekaa         North Indian, Chinese, Continental, Mangalorean
# Food Point                                             North Indian, Chinese
# Melange - Hotel Ekaa         North Indian, Chinese, Continental, Mangalorean
# Agarwal Food Service                          North Indian, Chinese, Biryani
# A2B - Adyar Ananda Bhavan  South Indian, North Indian, Chinese, Street Fo...
# Sri Lakshmi Dhaba                                               North Indian
# Sri Krishna Kitchen                                    North Indian, Chinese
# Melange - Hotel Ekaa         North Indian, Chinese, Continental, Mangalorean
# Swad Punjab Da                                                  North Indian
# Bitebox                             North Indian, Chinese, Mughlai, Desserts
# Mast Kalandar                                                   North Indian
# Ghar Ka Khana                                                   North Indian
# Melange - Hotel Ekaa         North Indian, Chinese, Continental, Mangalorean
# The Diner                             North Indian, Chinese, Andhra, Biryani
# Swad Punjab Da                                                  North Indian
#
#                            Mean Rating   cost
# Pai Vihar                         2.48  400.0
# Pai Vihar                         2.48  400.0
# Pai Vihar                         2.48  400.0
# Pai Vihar                         2.48  400.0
# Shree Thali                       3.94  150.0
# Shree Thali                       3.94  150.0
# Mast Kalandar                     1.72  450.0
# Mast Kalandar                     1.72  450.0
# Gokul Kuteera                     3.71  650.0
# Prasiddhi Food Corner             3.45  200.0
# Delhi Home Food                   2.94  200.0
# Delhi Home Food                   2.94  200.0
# Delhi Home Food                   2.94  200.0
# Punjabi Tasty Khana               2.68  450.0
# Prasiddhi Food Corner             3.45  200.0
# Punjabi Dawat                     2.42  400.0
# Melange - Hotel Ekaa              2.81  900.0
# Food Point                        2.94  300.0
# Melange - Hotel Ekaa              2.81  900.0
# Agarwal Food Service              3.39  400.0
# A2B - Adyar Ananda Bhavan         3.05  400.0
# Sri Lakshmi Dhaba                 2.50  250.0
# Sri Krishna Kitchen               3.34  350.0
# Melange - Hotel Ekaa              2.81  900.0
# Swad Punjab Da                    3.87  150.0
# Bitebox                           4.44  300.0
# Mast Kalandar                     1.72  450.0
# Ghar Ka Khana                     3.45  150.0
# Melange - Hotel Ekaa              2.81  900.0
# The Diner                         3.32  700.0
# Swad Punjab Da                    3.87  150.0
# # Drop the same named restaurants and sort only the top 10 by the highest rating
#                                                                     cuisines  \
# Gokul Kuteera                                          North Indian, Chinese
# Punjabi Tasty Khana                           North Indian, Chinese, Biryani
# Punjabi Dawat                                          North Indian, Chinese
# Food Point                                             North Indian, Chinese
# Agarwal Food Service                          North Indian, Chinese, Biryani
# A2B - Adyar Ananda Bhavan  South Indian, North Indian, Chinese, Street Fo...
# Sri Lakshmi Dhaba                                               North Indian
# Sri Krishna Kitchen                                    North Indian, Chinese
# Bitebox                             North Indian, Chinese, Mughlai, Desserts
# Ghar Ka Khana                                                   North Indian
# The Diner                             North Indian, Chinese, Andhra, Biryani
#
#                            Mean Rating   cost
# Gokul Kuteera                     3.71  650.0
# Punjabi Tasty Khana               2.68  450.0
# Punjabi Dawat                     2.42  400.0
# Food Point                        2.94  300.0
# Agarwal Food Service              3.39  400.0
# A2B - Adyar Ananda Bhavan         3.05  400.0
# Sri Lakshmi Dhaba                 2.50  250.0
# Sri Krishna Kitchen               3.34  350.0
# Bitebox                           4.44  300.0
# Ghar Ka Khana                     3.45  150.0
# The Diner                         3.32  700.0
#                                                                     cuisines  \
# Bitebox                             North Indian, Chinese, Mughlai, Desserts
# Gokul Kuteera                                          North Indian, Chinese
# Ghar Ka Khana                                                   North Indian
# Agarwal Food Service                          North Indian, Chinese, Biryani
# Sri Krishna Kitchen                                    North Indian, Chinese
# The Diner                             North Indian, Chinese, Andhra, Biryani
# A2B - Adyar Ananda Bhavan  South Indian, North Indian, Chinese, Street Fo...
# Food Point                                             North Indian, Chinese
# Punjabi Tasty Khana                           North Indian, Chinese, Biryani
# Sri Lakshmi Dhaba                                               North Indian
#
#                            Mean Rating   cost
# Bitebox                           4.44  300.0
# Gokul Kuteera                     3.71  650.0
# Ghar Ka Khana                     3.45  150.0
# Agarwal Food Service              3.39  400.0
# Sri Krishna Kitchen               3.34  350.0
# The Diner                         3.32  700.0
# A2B - Adyar Ananda Bhavan         3.05  400.0
# Food Point                        2.94  300.0
# Punjabi Tasty Khana               2.68  450.0
# Sri Lakshmi Dhaba                 2.50  250.0
# TOP 10 RESTAURANTS LIKE Pai Vihar WITH SIMILAR REVIEWS:
#                                                                     cuisines  \
# Bitebox                             North Indian, Chinese, Mughlai, Desserts
# Gokul Kuteera                                          North Indian, Chinese
# Ghar Ka Khana                                                   North Indian
# Agarwal Food Service                          North Indian, Chinese, Biryani
# Sri Krishna Kitchen                                    North Indian, Chinese
# The Diner                             North Indian, Chinese, Andhra, Biryani
# A2B - Adyar Ananda Bhavan  South Indian, North Indian, Chinese, Street Fo...
# Food Point                                             North Indian, Chinese
# Punjabi Tasty Khana                           North Indian, Chinese, Biryani
# Sri Lakshmi Dhaba                                               North Indian
#
#                            Mean Rating   cost
# Bitebox                           4.44  300.0
# Gokul Kuteera                     3.71  650.0
# Ghar Ka Khana                     3.45  150.0
# Agarwal Food Service              3.39  400.0
# Sri Krishna Kitchen               3.34  350.0
# The Diner                         3.32  700.0
# A2B - Adyar Ananda Bhavan         3.05  400.0
# Food Point                        2.94  300.0
# Punjabi Tasty Khana               2.68  450.0
# Sri Lakshmi Dhaba                 2.50  250.0
